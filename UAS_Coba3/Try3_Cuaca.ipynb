# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca dataset
df = pd.read_csv('cuaca_harian.csv')

# %%
# Menampilkan 5 baris pertama dari dataset
print("5 Baris Pertama Dataset:")
print(df.head())
# Out:
# 5 Baris Pertama Dataset:
#       Tanggal Nama_Kota  Suhu_Rata_Rata  Curah_Hujan   Kecepatan_Angin
# 0  2024-01-01   Jakarta              30            10               15
# 1  2024-01-01   Bandung              25             5               10
# 2  2024-01-01  Surabaya              32             0               20
# 3  2024-01-02     Medan              28            12               18
# 4  2024-01-02  Denpasar              29             8               12

# %%
# Informasi umum tentang dataset
print("\nInformasi Dataset:")
print(df.info())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tanggal          15 non-null     object
#  1   Nama_Kota        15 non-null     object
#  2   Suhu_Rata_Rata   15 non-null     int64
#  3   Curah_Hujan      15 non-null     int64
#  4   Kecepatan_Angin  15 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 732.0+ bytes
# None

# %%
# Statistik deskriptif dari dataset
print("\nStatistik Deskriptif:")
print(df.describe())
# Out:
# Statistik Deskriptif:
#        Suhu_Rata_Rata  Curah_Hujan   Kecepatan_Angin
# count       15.000000     15.000000        15.000000
# mean        29.000000      5.933333        15.000000
# std          2.828427      4.876572         4.971346
# min         24.000000      0.000000         8.000000
# 25%         27.500000      1.000000        11.500000
# 50%         29.000000      5.000000        14.000000
# 75%         30.500000     10.000000        19.000000
# max         34.000000     15.000000        25.000000

# %%
# Menampilkan kota yang terdapat dalam dataset
print("\nKota dalam Dataset:")
print(df['Nama_Kota'].unique())
# Out:
# Kota dalam Dataset:
# ['Jakarta' 'Bandung' 'Surabaya' 'Medan' 'Denpasar']

# %%
# Menghitung suhu rata-rata per kota
suhu_rata_rata_per_kota = df.groupby('Nama_Kota')['Suhu_Rata_Rata'].mean()
print("\nSuhu Rata-Rata per Kota:")
print(suhu_rata_rata_per_kota)
# Out:
# Suhu Rata-Rata per Kota:
# Nama_Kota
# Bandung     25.0
# Denpasar    29.0
# Jakarta     30.0
# Medan       28.0
# Surabaya    33.0
# Name: Suhu_Rata_Rata, dtype: float64

# %%
# Visualisasi suhu rata-rata per kota
plt.figure(figsize=(10, 6))
sns.barplot(x=suhu_rata_rata_per_kota.index, y=suhu_rata_rata_per_kota.values)
plt.title('Suhu Rata-Rata per Kota')
plt.xlabel('Kota')
plt.ylabel('Suhu Rata-Rata (°C)')
plt.show()

# %%
# Menghitung kecepatan angin rata-rata per kota
kecepatan_angin_rata_rata_per_kota = df.groupby('Nama_Kota')['Kecepatan_Angin'].mean()
print("\nKecepatan Angin Rata-Rata per Kota:")
print(kecepatan_angin_rata_rata_per_kota)
# Out:
# Kecepatan Angin Rata-Rata per Kota:
# Nama_Kota
# Bandung      9.666667
# Denpasar    13.000000
# Jakarta     12.333333
# Medan       17.666667
# Surabaya    22.333333
# Name: Kecepatan_Angin, dtype: float64

# %%
# Visualisasi kecepatan angin rata-rata per kota
plt.figure(figsize=(10, 6))
sns.barplot(x=kecepatan_angin_rata_rata_per_kota.index, y=kecepatan_angin_rata_rata_per_kota.values)
plt.title('Kecepatan Angin Rata-Rata per Kota')
plt.xlabel('Kota')
plt.ylabel('Kecepatan Angin (km/h)')
plt.show()

# %%
# Visualisasi curah hujan per kota
curah_hujan_per_kota = df.groupby('Nama_Kota')['Curah_Hujan'].sum()
plt.figure(figsize=(10, 6))
sns.barplot(x=curah_hujan_per_kota.index, y=curah_hujan_per_kota.values)
plt.title('Curah Hujan per Kota')
plt.xlabel('Kota')
plt.ylabel('Curah Hujan (mm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Visualisasi curah hujan per kota
# ----> 2 curah_hujan_per_kota = df.groupby('Nama_Kota')['Curah_Hujan'].sum()
#       3 plt.figure(figsize=(10, 6))
#       4 sns.barplot(x=curah_hujan_per_kota.index, y=curah_hujan_per_kota.values)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Curah_Hujan'
